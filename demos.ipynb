# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x1 = [i for i in range(100)]
y1= [j**2 for j in x1]
plt.plot(x1, y1, label = 'Square line')

#x2 = [i for i in range(100)]
y2= [2*j**2 for j in x1]
plt.plot(x1, y2, label = '2* square line')

plt.xlabel('Numbers')
plt.ylabel('Powers')
plt.legend()
plt.title('Interesting graph of squares\nand cubes')
plt.show()

# %%
x = [2,4,6,8,10]
x2=[1,3,5,7,9]
y=[6,8,12,56,22]
y2 = [f**2 for f in x]
plt.bar(x,y,color='r', label='bar1')
plt.bar(x2,y2,color='c', label='bar2')
plt.xlabel('Xs')
plt.ylabel('Ys')
plt.title('Interesting graph')
plt.legend()
plt.show()

# %%
import random
population_ages = [int(random.gauss(60,45)) for _ in range(100)]
population_ages =[ x for x in population_ages if x>0 and x<120]
#person_id = [i+1 for i in range(len(population_ages))]
bins = [i*10 for i in range(13)]
plt.hist(population_ages, bins, histtype ='bar', rwidth=0.8)
plt.text(6,8, 'Blah')
plt.show()

# %%
person_id = [i+1 for i in range(len(population_ages))]
plt.scatter(person_id, population_ages, label ='skitscat', color = 'k', marker = '*', s = 100)
plt.xlabel('Person ids')
plt.ylabel('Ages')
plt.legend()
plt.show()

# %%
#help(plt.stackplot)

x = [1,2,3,4,5]
sleeping=[7,8,6,5,4]
eating = [2,3,2,4,3]
working = [9,8,8,7,8]
playing = [6,5,8,8,9]

plt.stackplot(x, sleeping, eating, working, playing, labels = ('Sleeping', 'Eating', 'Working', 'Playing'), colors = ['r', 'g', 'c', 'b', 'y'])

plt.annotate('Text first - Bad news!', (2,8), xytext = (4,10), arrowprops=dict(facecolor='black', shrink=0.05))

plt.legend()
plt.show()

# %%
#help(plt.pie)

slices = [7,2,2,13] ##add upto something. in this case 24 hours ##
activities = ['sleeping', 'eating', 'playing', 'working']
colrs = ['g', 'r', 'y' , 'c' ]
plt.pie(slices, labels = activities, colors = colrs, startangle = 90, explode = [0,0.1,0.6,0], autopct='%1.1f%%')
plt.show()

# %%
#person_id = [i+1 for i in range(len(population_ages))]
#fig,ax = plt.subplots(4) can always do this then refer by 0,1,2,3


fig, ax = plt.subplots(2,2)
for axis in ax.flat:
    axis.set(xlabel='x-label', ylabel='y-label')
    
ax[0,0].plot([x for x in range(25)], [y**2 for y in range(25)])

ax[0,0].grid(True)#, color = 'g', linestyle = '-', linewidth = 5)
ax[0,0].set_yticks([0,100,200,300,500,1000])
ax[0,0].tick_params(axis = 'y', rotation = 45)

x0 = [x for x in range(25)]
y0= [y**3 for y in range(25)]
ax[0,1].plot(x0, y0)
ax[0,1].fill_between(x0,y0, 5000,alpha = 0.3)
ax[0,1].axhline(y0[7], linewidth = 2)

ax[1,0].plot(x0, y0)
ax[1,0].fill_between(x0,y0, y0[0],alpha = 0.3)
ax[1,0].text(8,3000, 'Blah blah')


ax[1,1].plot(x0, y0)
ax[1,1].fill_between(x0,y0,facecolor='r',alpha = 0.3)
ax[1,1].spines['left'].set_color('c')
ax[1,1].spines['left'].set_linewidth(3)
ax[1,1].spines['top'].set_visible(False)
ax[1,1].tick_params(axis = 'x',labelrotation=45)
#ax[1,1].annotate('Text first - Bad news!', (x0[2], y0[3]), xytext = (0.8, 0.9), textcoords = 'axes fraction')
                   



plt.show()

# %%
from matplotlib import style
style.use('ggplot')


person_id = [i+1 for i in range(len(population_ages))]
plt.scatter(person_id, population_ages, label ='skitscat', color = 'k', marker = '*', s = 10)
plt.xlabel('Person ids')
plt.ylabel('Ages')
plt.legend()
plt.show()

# %%
from matplotlib import style
style.use('fivethirtyeight')


person_id = [i+1 for i in range(len(population_ages))]
plt.scatter(person_id, population_ages, label ='skitscat', color = 'k', marker = '*', s = 10)
plt.xlabel('Person ids')
plt.ylabel('Ages')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import style
style.use('fivethirtyeight')

fig, ax1 = plt.subplots(1)
def animate(i):
    graph_data = open('C:\\Contents\\Txt\\example.txt','r').read()
    lines = graph_data.split('\n')
    xs = []
    ys = []
    for line in lines:
        if len(line) > 1:
            x, y = line.split(',')
            xs.append(float(x))
            ys.append(float(y))
    ax1.clear()
    ax1.plot(xs, ys)

ani = animation.FuncAnimation(fig, animate, interval=10)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = ax.plot(t, s, lw=2)

ax.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )
ax.set_ylim(-2, 2)
plt.show()

# %%
import random
import matplotlib.pyplot as plt
from matplotlib import style

style.use('fivethirtyeight')

fig = plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
def create_plots():
    xs = []
    ys = []

    for i in range(10):
        x = i
        y = random.randrange(10)

        xs.append(x)
        ys.append(y)
    return xs, ys

ax1 = plt.subplot2grid((6,1), (0,0), rowspan=1, colspan=1)
ax2 = plt.subplot2grid((6,1), (1,0), rowspan=4, colspan=1)
ax3 = plt.subplot2grid((6,1), (5,0), rowspan=1, colspan=1)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Some example data to display
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('A single plot')

plt.show()
/***********************************************************/

# %%
fig, axs = plt.subplots(2)
fig.suptitle('Vertically stacked subplots')
axs[0].plot(x, y)
axs[1].plot(x, -y)

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Horizontally stacked subplots')
ax1.plot(x, y)
ax2.plot(x, -y)

plt.show()

# %%
## Align horizonal or vertical axes usin this
fig, (ax1, ax2) = plt.subplots(2, sharex=True)
fig.suptitle('Aligning x-axis using sharex')
ax1.plot(x, y)
ax2.plot(x + 1, -y)
plt.show()

# %%
## Both x and y have same scale

fig, axs = plt.subplots(3, sharex=True, sharey=True)
fig.suptitle('Sharing both axes')
axs[0].plot(x, y ** 2)
axs[1].plot(x, 0.3 * y, 'o')
axs[2].plot(x, y, '+')

plt.show()
